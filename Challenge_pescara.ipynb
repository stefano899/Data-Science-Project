# %% [markdown]
# # Data Analytics and Data Driven Decision 2024

# %% [markdown]
# ## The final challenge
#
# Your startup company **Connect-them-all** wants to deploy a backbone network to
# provide high-speed Internet connections in Abruzzo.
#
# Your Chief Financial Officer has reserved a budget of 25,000 Euro for the realization of the network.
# As data guru, you are in charge of:
#
# 1. **Estimate the sales in each city contained in the dataset** `abruzzo_cities.csv`.
#
#     To this aim,
#     the marketing department has provided you with a dataset `italian_cities.csv` that reports the population (in tens of thousand) and the number of contracts sold in 50 Italian cities last year. Using this dataset, you have to:
#
#     1. Train a regression model that, for a given city, estimates the number of contracts (**target**) based on city's population (**feature**).
#     2. Run the trained model to predict the contract sales for the 32 main Abruzzo cities in `abruzzo_cities.csv`
#
#
# 2. **Design the most profitable backbone network**, knowing that:
#
#     1. The activation cost of the link between city $i$ and $j$ is $100 *  \text{distance} (i,j)$ Euro, where  $\text{distance} (i,j)$ is reported in the dataset `distances.csv`. The total network cost is the sum of the costs of the activated links.
#
#     2. Each connected city will return a revenue of $10 * \text{estimated contract sales}$ Euro
#
#     3. The network can be rooted either in Pescara or in Avezzano

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import gurobipy as gb

# %% [markdown]
# We load the datasets.

# %%
italian_cities_df = pd.read_csv('italian_cities.csv')
abruzzo_cities_df = pd.read_csv('abruzzo_cities.csv', index_col="city", sep = ",")
distances_df = pd.read_csv('distances.csv', index_col="city", sep = ";")

# %% [markdown]
# We perform a reshaping of the loaded datasets, in particular we converted the column vectors into 2-dimensional arrays with a single column. This is important because many `Scikit-Learn` functions require input data to be 2-dimensional arrays, even if they have only one feature.

# %%
X = italian_cities_df['population'].values.reshape(-1, 1)
y = italian_cities_df['contracts'].values.reshape(-1, 1)

plt.scatter(X, y)

# %% [markdown]
# Now we are ready to train the regressor. Note that we decided to split the `italian_cities.csv` so that the **80% of data are used for training purpose, the remaining 20% for testing**.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
poly_object = PolynomialFeatures(degree=4)
X_train_poly = poly_object.fit_transform(X_train)

LinearRegression_model = LinearRegression(fit_intercept=True)
LinearRegression_model.fit(X_train_poly, y_train)

y_predicted = LinearRegression_model.predict(X_train_poly)

X_test_poly = poly_object.fit_transform(X_test)

y_test_predicted = LinearRegression_model.predict(X_test_poly)

# %% [markdown]
# The **R square** score will give us an idea of how the regression performed. After that we plot the results.

# %%
r2_train = r2_score(y_train, y_predicted)
print(r2_train)
# Out:
# 0.9632627965928597

# %%
plt.figure(figsize=(10, 6))

# In red the training data
plt.scatter(X_train, y_train, color='red', label='Training data')

# In blue the prediction for the training set
plt.plot(sorted(X_train), y_predicted[np.argsort(X_train.ravel())], color='blue', label='Model fit (training)')

# In green the tessting data
plt.scatter(X_test, y_test, color='green', label='Test data')

# In orange the predicition for the testing set
plt.plot(sorted(X_test), y_test_predicted[np.argsort(X_test.ravel())], color='orange', linestyle='--', label='Model fit (test)')

# %%
abruzzo_cities_df['predicted_contracts'] = LinearRegression_model.predict(poly_object.fit_transform(abruzzo_cities_df['population'].values.reshape(-1, 1)))

results_dict = abruzzo_cities_df['predicted_contracts'].to_dict()

# %%
print(results_dict)
# Out:
# {'Pescara': 3153.2115821467582, 'LAquila': 2534.5886945110005, 'Teramo': 2174.452313092196, 'Chieti': 2087.0122842294886, 'Montesilvano': 2053.1250639887057, 'Avezzano': 1737.1329909021574, 'Vasto': 1670.521405674621, 'Lanciano': 1576.1255538008863, 'RosetodegliAbruzzi': 1216.8389981645141, 'Sulmona': 1195.9152462119168, 'FrancavillaalMare': 1181.5553956257245, 'Ortona': 1169.3781762641038, 'Giulianova': 1162.3635369739732, 'SanSalvo': 1031.1783018606684, 'Spoltore': 1022.958968260745, 'Martinsicuro': 935.7616183956538, 'Silvi': 933.4845252838815, 'Pineto': 912.5506337915903, 'CittaSantAngelo': 905.7758641528617, 'SanGiovanniTeatino': 862.4934213890979, 'Penne': 862.0812014990793, 'AlbaAdriatica': 832.8517109784411, 'Atri': 821.6073978195964, 'Celano': 814.6319338630603, 'Atessa': 812.9947238596574, 'Cepagatti': 805.413409356501, 'Tortoreto': 805.2441269038029, 'SantEgidioallaVibrata': 786.7494764420478, 'Guardiagrele': 779.6784608563325, 'MoscianoSantAngelo': 776.9718726257975, 'Pianella': 758.2730037318054, 'MontorioalVomano': 752.9495084995176}

# %%
abruzzo_cities_df.index
# Out:
# Index(['Pescara', 'LAquila', 'Teramo', 'Chieti', 'Montesilvano', 'Avezzano',
#        'Vasto', 'Lanciano', 'RosetodegliAbruzzi', 'Sulmona',
#        'FrancavillaalMare', 'Ortona', 'Giulianova', 'SanSalvo', 'Spoltore',
#        'Martinsicuro', 'Silvi', 'Pineto', 'CittaSantAngelo',
#        'SanGiovanniTeatino', 'Penne', 'AlbaAdriatica', 'Atri', 'Celano',
#        'Atessa', 'Cepagatti', 'Tortoreto', 'SantEgidioallaVibrata',
#        'Guardiagrele', 'MoscianoSantAngelo', 'Pianella', 'MontorioalVomano'],
#       dtype='object', name='city')

# %%
G = nx.complete_graph(abruzzo_cities_df.index)

# %%
nx.set_node_attributes(G, abruzzo_cities_df['longitude'], 'x')
nx.set_node_attributes(G, abruzzo_cities_df['latitude'], 'y')
nx.set_node_attributes(G, abruzzo_cities_df['population']*10000, 'population')
nx.set_node_attributes(G, results_dict, 'predicted_sale')

# %%
for i in G.nodes():
    for j in G.nodes():
        if i != j:
            G[i][j]['costo_att'] = distances_df.loc[i, j] * 100

# %%
G.edges(data = True)
# Out:
# EdgeDataView([('Pescara', 'LAquila', {'costo_att': 6700}), ('Pescara', 'Teramo', {'costo_att': 4600}), ('Pescara', 'Chieti', {'costo_att': 1400}), ('Pescara', 'Montesilvano', {'costo_att': 600}), ('Pescara', 'Avezzano', {'costo_att': 8000}), ('Pescara', 'Vasto', {'costo_att': 5600}), ('Pescara', 'Lanciano', {'costo_att': 3000}), ('Pescara', 'RosetodegliAbruzzi', {'costo_att': 2700}), ('Pescara', 'Sulmona', {'costo_att': 5000}), ('Pescara', 'FrancavillaalMare', {'costo_att': 800}), ('Pescara', 'Ortona', {'costo_att': 2100}), ('Pescara', 'Giulianova', {'costo_att': 3700}), ('Pescara', 'SanSalvo', {'costo_att': 6300}), ('Pescara', 'Spoltore', {'costo_att': 700}), ('Pescara', 'Martinsicuro', {'costo_att': 5100}), ('Pescara', 'Silvi', {'costo_att': 1100}), ('Pescara', 'Pineto', {'costo_att': 1900}), ('Pescara', 'CittaSantAngelo', {'costo_att': 1300}), ('Pescara', 'SanGiovanniTeatino', {'costo_att': 600}), ('Pescara', 'Penne', {'costo_att': 2200}), ('Pescara', 'AlbaAdriatica', {'costo_att': 4600}), ('Pescara', 'Atri', {'costo_att': 2200}), ('Pescara', 'Celano', {'costo_att': 6900}), ('Pescara', 'Atessa', {'costo_att': 4800}), ('Pescara', 'Cepagatti', {'costo_att': 1600}), ('Pescara', 'Tortoreto', {'costo_att': 4400}), ('Pescara', 'SantEgidioallaVibrata', {'costo_att': 5500}), ('Pescara', 'Guardiagrele', {'costo_att': 3000}), ('Pescara', 'MoscianoSantAngelo', {'costo_att': 4000}), ('Pescara', 'Pianella', {'costo_att': 1500}), ('Pescara', 'MontorioalVomano', {'costo_att': 4800}), ('LAquila', 'Teramo', {'costo_att': 4200}), ('LAquila', 'Chieti', {'costo_att': 6300}), ('LAquila', 'Montesilvano', {'costo_att': 6400}), ('LAquila', 'Avezzano', {'costo_att': 3400}), ('LAquila', 'Vasto', {'costo_att': 11000}), ('LAquila', 'Lanciano', {'costo_att': 8200}), ('LAquila', 'RosetodegliAbruzzi', {'costo_att': 6200}), ('LAquila', 'Sulmona', {'costo_att': 5300}), ('LAquila', 'FrancavillaalMare', {'costo_att': 7300}), ('LAquila', 'Ortona', {'costo_att': 8200}), ('LAquila', 'Giulianova', {'costo_att': 6400}), ('LAquila', 'SanSalvo', {'costo_att': 11400}), ('LAquila', 'Spoltore', {'costo_att': 6100}), ('LAquila', 'Martinsicuro', {'costo_att': 7300}), ('LAquila', 'Silvi', {'costo_att': 6300}), ('LAquila', 'Pineto', {'costo_att': 6200}), ('LAquila', 'CittaSantAngelo', {'costo_att': 5700}), ('LAquila', 'SanGiovanniTeatino', {'costo_att': 6600}), ('LAquila', 'Penne', {'costo_att': 4500}), ('LAquila', 'AlbaAdriatica', {'costo_att': 6900}), ('LAquila', 'Atri', {'costo_att': 5400}), ('LAquila', 'Celano', {'costo_att': 3100}), ('LAquila', 'Atessa', {'costo_att': 9200}), ('LAquila', 'Cepagatti', {'costo_att': 5500}), ('LAquila', 'Tortoreto', {'costo_att': 6500}), ('LAquila', 'SantEgidioallaVibrata', {'costo_att': 5800}), ('LAquila', 'Guardiagrele', {'costo_att': 6900}), ('LAquila', 'MoscianoSantAngelo', {'costo_att': 5900}), ('LAquila', 'Pianella', {'costo_att': 5300}), ('LAquila', 'MontorioalVomano', {'costo_att': 3200}), ('Teramo', 'Chieti', {'costo_att': 5200}), ('Teramo', 'Montesilvano', {'costo_att': 4000}), ('Teramo', 'Avezzano', {'costo_att': 7300}), ('Teramo', 'Vasto', {'costo_att': 10200}), ('Teramo', 'Lanciano', {'costo_att': 7400}), ('Teramo', 'RosetodegliAbruzzi', {'costo_att': 2500}), ('Teramo', 'Sulmona', {'costo_att': 6800}), ('Teramo', 'FrancavillaalMare', {'costo_att': 5500}), ('Teramo', 'Ortona', {'costo_att': 6700}), ('Teramo', 'Giulianova', {'costo_att': 2400}), ('Teramo', 'SanSalvo', {'costo_att': 10900}), ('Teramo', 'Spoltore', {'costo_att': 4300}), ('Teramo', 'Martinsicuro', {'costo_att': 3000}), ('Teramo', 'Silvi', {'costo_att': 3600}), ('Teramo', 'Pineto', {'costo_att': 3000}), ('Teramo', 'CittaSantAngelo', {'costo_att': 3300}), ('Teramo', 'SanGiovanniTeatino', {'costo_att': 4900}), ('Teramo', 'Penne', {'costo_att': 2900}), ('Teramo', 'AlbaAdriatica', {'costo_att': 2600}), ('Teramo', 'Atri', {'costo_att': 2400}), ('Teramo', 'Celano', {'costo_att': 6500}), ('Teramo', 'Atessa', {'costo_att': 9000}), ('Teramo', 'Cepagatti', {'costo_att': 45 ...

# %%
G.nodes(data = True)
# Out:
# NodeDataView({'Pescara': {'x': 14.2059269, 'y': 42.469613, 'population': 117166.0, 'predicted_sale': 3153.2115821467582}, 'LAquila': {'x': 13.3979672, 'y': 42.3489203, 'population': 66964.0, 'predicted_sale': 2534.5886945110005}, 'Teramo': {'x': 13.6983524, 'y': 42.6612893, 'population': 54294.0, 'predicted_sale': 2174.452313092196}, 'Chieti': {'x': 14.1659738, 'y': 42.3446529, 'population': 51484.0, 'predicted_sale': 2087.0122842294886}, 'Montesilvano': {'x': 14.1516203, 'y': 42.5136032, 'population': 50413.0, 'predicted_sale': 2053.1250639887057}, 'Avezzano': {'x': 13.4265048, 'y': 42.0347963, 'population': 40744.0, 'predicted_sale': 1737.1329909021574}, 'Vasto': {'x': 14.705923, 'y': 42.12434, 'population': 38747.0, 'predicted_sale': 1670.521405674621}, 'Lanciano': {'x': 14.3907794, 'y': 42.2305316, 'population': 35921.0, 'predicted_sale': 1576.1255538008863}, 'RosetodegliAbruzzi': {'x': 14.0144636, 'y': 42.677577, 'population': 24940.000000000004, 'predicted_sale': 1216.8389981645141}, 'Sulmona': {'x': 13.92879944, 'y': 42.06903495, 'population': 24275.000000000004, 'predicted_sale': 1195.9152462119168}, 'FrancavillaalMare': {'x': 14.28701, 'y': 42.420643, 'population': 23816.0, 'predicted_sale': 1181.5553956257245}, 'Ortona': {'x': 14.403913, 'y': 42.349643, 'population': 23424.999999999996, 'predicted_sale': 1169.3781762641038}, 'Giulianova': {'x': 13.9667011, 'y': 42.7534856, 'population': 23199.0, 'predicted_sale': 1162.3635369739732}, 'SanSalvo': {'x': 14.7272302, 'y': 42.0433265, 'population': 18848.0, 'predicted_sale': 1031.1783018606684}, 'Spoltore': {'x': 14.13102149, 'y': 42.43808215, 'population': 18566.0, 'predicted_sale': 1022.958968260745}, 'Martinsicuro': {'x': 13.9155354, 'y': 42.8851442, 'population': 15484.0, 'predicted_sale': 935.7616183956538}, 'Silvi': {'x': 14.1187686, 'y': 42.5487923, 'population': 15401.0, 'predicted_sale': 933.4845252838815}, 'Pineto': {'x': 14.0671028, 'y': 42.6077714, 'population': 14631.0, 'predicted_sale': 912.5506337915903}, 'CittaSantAngelo': {'x': 14.059203, 'y': 42.518144, 'population': 14379.0, 'predicted_sale': 905.7758641528617}, 'SanGiovanniTeatino': {'x': 14.2010296, 'y': 42.4105412, 'population': 12733.000000000002, 'predicted_sale': 862.4934213890979}, 'Penne': {'x': 13.9273256, 'y': 42.4582153, 'population': 12717.0, 'predicted_sale': 862.0812014990793}, 'AlbaAdriatica': {'x': 13.927816, 'y': 42.8343422, 'population': 11565.0, 'predicted_sale': 832.8517109784411}, 'Atri': {'x': 13.9764121, 'y': 42.5801368, 'population': 11112.0, 'predicted_sale': 821.6073978195964}, 'Celano': {'x': 13.5462069, 'y': 42.0843238, 'population': 10828.0, 'predicted_sale': 814.6319338630603}, 'Atessa': {'x': 14.4489025, 'y': 42.0718059, 'population': 10761.0, 'predicted_sale': 812.9947238596574}, 'Cepagatti': {'x': 14.0717952, 'y': 42.3643016, 'population': 10449.0, 'predicted_sale': 805.413409356501}, 'Tortoreto': {'x': 13.912405, 'y': 42.8039836, 'population': 10442.0, 'predicted_sale': 805.2441269038029}, 'SantEgidioallaVibrata': {'x': 13.717891, 'y': 42.821048, 'population': 9668.0, 'predicted_sale': 786.7494764420478}, 'Guardiagrele': {'x': 14.2197122, 'y': 42.1954758, 'population': 9367.0, 'predicted_sale': 779.6784608563325}, 'MoscianoSantAngelo': {'x': 13.888296, 'y': 42.746847, 'population': 9251.0, 'predicted_sale': 776.9718726257975}, 'Pianella': {'x': 14.0462697, 'y': 42.3960111, 'population': 8437.0, 'predicted_sale': 758.2730037318054}, 'MontorioalVomano': {'x': 13.6325193, 'y': 42.5827062, 'population': 8201.0, 'predicted_sale': 752.9495084995176}})

# %%
def DrawInitG(G, withedges=False):
    
    plt.figure(figsize=args.figsize)
    
    pos = {i:(G.nodes[i]['x'], G.nodes[i]['y']) for i in G.nodes()}
    
    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o', 
                           node_size=600,
                           node_color='red')
    
    nx.draw_networkx_labels(G, pos=pos, font_color='w', font_size=12)
    
    if withedges:
        nx.draw_networkx_edges(G,pos=pos, alpha=1.0)
        labels = {(i,j):G.get_edge_data(i,j,'costo_att').get('costo_att') for i,j in G.edges()}
        nx.draw_networkx_edge_labels(G, pos=pos, edge_labels=labels)
    
    plt.axis('off')
    plt.show()
def DrawSol(G, x):
    
    plt.figure(figsize=args.figsize)
    
    pos = {i:(G.nodes[i]['x'], G.nodes[i]['y']) for i in G.nodes()}

    
    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o', 
                           node_size=600,
                           node_color='red',
                           label=[G.nodes()])
    
    nx.draw_networkx_labels(G, pos=pos, font_color='w', font_size=12)
    
    for u,v in G.edges():
        if x[u,v].x > 0.01 and x[u,v].x < 0.9:
            nx.draw_networkx_edges(G, pos=pos,
                                   edgelist=[(u,v)],
                                   edge_color='r')
            
            nx.draw_networkx_edge_labels(G, pos=pos,
                                         edge_labels={(u,v):'{:.2f}'.format(x[u,v].x)})
        
        if x[u,v].x > 0.9:
            nx.draw_networkx_edges(G, pos=pos,
                                   edgelist=[(u,v)],
                                   edge_color='k')
        

    
    #edges_in_sol = [(u,v)  for u,v in G.edges() if x[u,v].x > 0.1]

    
    plt.axis('off')
    plt.show()
    
class args:
    filename = None
    figsize = 30,60
    scale = 40

# %%
D = G.to_directed()

# %%
root = 'Pescara'

pos = {i:(G.nodes[i]['x'] * args.scale,G.nodes[i]['y'] * args.scale) for i in G.nodes()}
DrawInitG(G)

# %%
pcst = gb.Model()
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2487592
# Academic license 2487592 - for non-commercial use only - registered to lo___@student.univaq.it

# %%
#
# Variables definition
#


x = pcst.addVars(D.edges(), vtype=gb.GRB.BINARY, \
                 obj = [- D[i][j]['costo_att'] for i,j in D.edges()], \
                 name = 'x')

y = pcst.addVars (G.nodes(), vtype = gb.GRB.BINARY, \
                  obj = [G.nodes[i]['predicted_sale']*10 for i in G.nodes()],\
                 name = 'y')

u = pcst.addVars (G.nodes(), vtype = gb.GRB.CONTINUOUS, 
                  lb = 0.0, ub = G.number_of_nodes(),\
                 name = 'u')


pcst.ModelSense = gb.GRB.MAXIMIZE

# %%
pcst.write('pcst.lp')

# %%
#
# Root is in the solution
#

pcst.addConstr(y[root] == 1, name = 'Fix')

pcst.update()

# %%
#
# Each node has exactly one incoming arc
#

pcst.addConstrs((x.sum('*',j) == y[j] for j in G.nodes() if j != root), name='Node')

pcst.update()

# %%
pcst.write('pcst.lp')

# %%
#
# Precedence constraints (MTZ constraints)
#

pcst.addConstrs(((G.number_of_nodes() +  1) * x[i,j] + u[i] - u[j] 
                 <= G.number_of_nodes() for i,j in D.edges()),
                name = 'MTZ')

pcst.update()

# %%
pcst.write('pcst.lp')

# %%
#
# Connectivity constraints
#

pcst.addConstrs((x[j,k] <= y[j] for j in G.nodes() \
                 if j != root for k in D.neighbors(j)), name = 'Connect')
pcst.update()

# %%
pcst.write('pcst.lp')

# %%
pcst.optimize()
# Out:
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: AMD Ryzen 7 7730U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2487592 - for non-commercial use only - registered to lo___@student.univaq.it
# Optimize a model with 1985 rows, 1056 columns and 5891 nonzeros
# Model fingerprint: 0xe9a90869
# Variable types: 32 continuous, 1024 integer (1024 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e+02, 3e+04]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 31532.115821
# Presolve removed 63 rows and 33 columns
# Presolve time: 0.02s
# Presolved: 1922 rows, 1023 columns, 5704 nonzeros
# Variable types: 31 continuous, 992 integer (992 binary)
#
# Root relaxation: objective 3.614739e+05, 65 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 361473.866    0   12 31532.1158 361473.866  1046%     -    0s
# H    0     0                    355058.71401 361473.866  1.81%     -    0s
# H    0     0                    356558.71401 361473.866  1.38%     -    0s
#      0     0 356858.714    0    2 356558.714 356858.714  0.08%     -    0s
#      0     0 infeasible    0      356558.714 356558.714  0.00%     -    0s
#
# Explored 1 nodes (113 simplex iterations) in 0.18 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 356559 355059 31532.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.565587140116e+05, best bound 3.565587140116e+05, gap 0.0000%

# %%
totalcost = 0

for i,j in D.edges():
        if x[i,j].x > 0.1:
            print (x[i,j])
            totalcost += D[i][j]['costo_att']

print ("Total cost", totalcost)
# Out:
# <gurobi.Var x[Pescara,Montesilvano] (value 1.0)>
# <gurobi.Var x[Pescara,SanGiovanniTeatino] (value 1.0)>
# <gurobi.Var x[Teramo,MontorioalVomano] (value 1.0)>
# <gurobi.Var x[Montesilvano,Silvi] (value 1.0)>
# <gurobi.Var x[Vasto,SanSalvo] (value 1.0)>
# <gurobi.Var x[Lanciano,Atessa] (value 1.0)>
# <gurobi.Var x[Lanciano,Guardiagrele] (value 1.0)>
# <gurobi.Var x[RosetodegliAbruzzi,Giulianova] (value 1.0)>
# <gurobi.Var x[Sulmona,Celano] (value 1.0)>
# <gurobi.Var x[FrancavillaalMare,Ortona] (value 1.0)>
# <gurobi.Var x[Ortona,Lanciano] (value 1.0)>
# <gurobi.Var x[Giulianova,MoscianoSantAngelo] (value 1.0)>
# <gurobi.Var x[Spoltore,Pianella] (value 1.0)>
# <gurobi.Var x[Silvi,Pineto] (value 1.0)>
# <gurobi.Var x[Silvi,CittaSantAngelo] (value 1.0)>
# <gurobi.Var x[Pineto,RosetodegliAbruzzi] (value 1.0)>
# <gurobi.Var x[Pineto,Atri] (value 1.0)>
# <gurobi.Var x[SanGiovanniTeatino,Chieti] (value 1.0)>
# <gurobi.Var x[SanGiovanniTeatino,FrancavillaalMare] (value 1.0)>
# <gurobi.Var x[SanGiovanniTeatino,Spoltore] (value 1.0)>
# <gurobi.Var x[AlbaAdriatica,Martinsicuro] (value 1.0)>
# <gurobi.Var x[Celano,LAquila] (value 1.0)>
# <gurobi.Var x[Celano,Avezzano] (value 1.0)>
# <gurobi.Var x[Atessa,Vasto] (value 1.0)>
# <gurobi.Var x[Tortoreto,AlbaAdriatica] (value 1.0)>
# <gurobi.Var x[Tortoreto,SantEgidioallaVibrata] (value 1.0)>
# <gurobi.Var x[SantEgidioallaVibrata,Teramo] (value 1.0)>
# <gurobi.Var x[Guardiagrele,Sulmona] (value 1.0)>
# <gurobi.Var x[MoscianoSantAngelo,Tortoreto] (value 1.0)>
# <gurobi.Var x[Pianella,Penne] (value 1.0)>
# <gurobi.Var x[Pianella,Cepagatti] (value 1.0)>
# Total cost 34700

# %%
args.figsize = (15,25)

DrawSol(D,x)

# %%
budget = 25000

costs ={(i,j): D[i][j]['costo_att'] for (i,j) in D.edges()}

# %%
pcst.addConstr(x.prod(costs) <= budget, 'Budget')

pcst.update() 

pcst.write('pcst_budget.lp')

# %%
pcst.reset()
pcst.optimize()
# Out:
# Discarded solution information
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: AMD Ryzen 7 7730U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2487592 - for non-commercial use only - registered to lo___@student.univaq.it
# Optimize a model with 1986 rows, 1056 columns and 6883 nonzeros
# Model fingerprint: 0xa09b7afd
# Variable types: 32 continuous, 1024 integer (1024 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [3e+02, 3e+04]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 31532.115821
# Presolve removed 63 rows and 33 columns
# Presolve time: 0.06s
# Presolved: 1923 rows, 1023 columns, 6665 nonzeros
# Variable types: 31 continuous, 992 integer (992 binary)
#
# Root relaxation: objective 3.449430e+05, 73 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 344943.048    0   24 31532.1158 344943.048   994%     -    0s
# H    0     0                    125602.22126 344943.048   175%     -    0s
# H    0     0                    134227.15548 344943.048   157%     -    0s
# H    0     0                    217223.20935 344943.048  58.8%     -    0s
#      0     0 316210.049    0   22 217223.209 316210.049  45.6%     -    0s
# H    0     0                    232619.05835 315722.045  35.7%     -    0s
# H    0     0                    296666.87368 315722.045  6.42%     -    0s
# H    0     0                    305496.82091 315587.667  3.30%     -    0s
#      0     0 315587.667    0   22 305496.821 315587.667  3.30%     -    0s
#      0     0 314080.261    0   16 305496.821 314080.261  2.81%     -    0s
#      0     0 314080.261    0   24 305496.821 314080.261  2.81%     -    0s
#      0     0 314080.261    0   20 305496.821 314080.261  2.81%     -    0s
#      0     0 314080.261    0    6 305496.821 314080.261  2.81%     -    0s
#      0     0 314059.867    0   15 305496.821 314059.867  2.80%     -    0s
#      0     0 314059.867    0   15 305496.821 314059.867  2.80%     -    0s
#      0     0 313870.395    0   23 305496.821 313870.395  2.74%     -    0s
# H    0     0                    313117.63293 313870.395  0.24%     -    0s
#      0     0 313317.633    0   10 313117.633 313317.633  0.06%     -    0s
#      0     0 313317.633    0   10 313117.633 313317.633  0.06%     -    0s
#      0     0 313317.633    0    6 313117.633 313317.633  0.06%     -    0s
#      0     0 infeasible    0      313117.633 313117.633  0.00%     -    0s
#
# Explored 1 nodes (354 simplex iterations) in 0.85 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 8: 313118 305497 296667 ... 31532.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.131176329288e+05, best bound 3.131176329288e+05, gap 0.0000%

# %%
DrawSol(D,x)

# %% [markdown]
# # predicted sol:
# 3.131176329288e+05
